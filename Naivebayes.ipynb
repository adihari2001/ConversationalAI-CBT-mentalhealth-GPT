# %% [markdown]
# <a href="https://colab.research.google.com/github/adihari2001/ProgrammingAssignment2/blob/master/Naivebayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
cd Emotion-Detector
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Emotion-Detector

# %%
from __future__ import division
import nltk 
import re
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import *
from textblob.classifiers import NaiveBayesClassifier
from sklearn.model_selection import KFold
from nltk.classify.naivebayes import NaiveBayesClassifier
from gensim import corpora, models, similarities
from nltk.corpus import wordnet as wn
import urllib
# Uncomment if using AlchemyAPI
# from alchemyapi import AlchemyAPI
# alchemyapi = AlchemyAPI()

# %%
'''
Reading the Dataset (ISEAR Dataset)
'''
Data = pd.read_csv('ISEAR.csv',header=None)
'''
36 - Class Label
40 - Sentence
'''
# Out:
# '\n36 - Class Label\n40 - Sentence\n'

# %%
'''
Emotion Labels
'''
emotion_labels = ['joy', 'fear', 'anger', 'sadness', 'disgust', 'shame', 'guilt']
# emotion_labels = ['joy', 'fear', 'anger', 'sadness', 'disgust']
'''
Negation words
'''
negation_words = ['not', 'neither', 'nor', 'but', 'however', 'although', 'nonetheless', 'despite', 'except', 'even though', 'yet']

# %%
'''
Returns a list of all corresponding class labels
'''
def class_labels(emotions):
    labels = []
    labelset = []
    exclude = []
    for i in range(len(emotions)):
#         labels.append(e)
#         labelset.append([e])
        if emotions[i] not in ['shame','guilt']:
            labels.append(e)
            labelset.append([e])
        else:
            exclude.append(i)
    return labels, labelset, exclude

# %%
'''
Removes unnecessary characters from sentences
'''
def removal(sentences):
    sentence_list = []
    count = 0
#     for sen in sentences:
#         count += 1
#         print count
#         print sen
#         print type(sen)
    s = nltk.word_tokenize(sentences)
    characters = ["á", "\xc3", "\xa1", "\n", ",", ".", "[", "]", ""]
    l = []
    for t in s:
        if t not in characters:
            l.append(t)
    return l
#     new = ' '.join([i for i in s if not [e for e in characters if e in i]])
#     print new
#     sentence_list.append(new)
#     return sentence_list

# %%
'''
POS-TAGGER, returns NAVA words
'''
def pos_tag(sentences):
    tags = [] #have the pos tag included
    nava_sen = []
    pt = nltk.pos_tag(sentences)
#     for s in sentences:
#     s_token = nltk.word_tokenize(sentences)
#     pt = nltk.pos_tag(s_token)
    nava = []
    nava_words = []
    for t in pt:
        if t[1].startswith('NN') or t[1].startswith('JJ') or t[1].startswith('VB') or t[1].startswith('RB'):
            nava.append(t)
            nava_words.append(t[0])
    return nava, nava_words
#     tags.append(nava)
#     nava_sen.append(nava_words)
#     return tags, nava_sen

# %%
'''
Performs stemming
'''
def stemming(sentences):
    sentence_list = []
    sen_string = []
    sen_token = []
    stemmer = PorterStemmer()
    i = 0
#     for sen in sentences:
#         print i,
    i += 1
    st = ""
    for word in sentences:
        word_l = word.lower()
        if len(word_l) >= 3:
            st += stemmer.stem(word_l) + " "
    sen_string.append(st)
    w_set = nltk.word_tokenize(st)
    sen_token.append(w_set)
    w_text = nltk.Text(w_set)
    sentence_list.append(w_text)
    return w_text, st, w_set
#     return sentence_list, sen_string, sen_token

# %%
'''
Write to file
'''
def write_to_file(filename, text):
    o = open(filename,'w')
    o.write(str(text))
    o.close()

# %%
'''
Creating the dataframe
'''
def create_frame(Data):
    labels = []
#     sentences = []
#     sen_string = []
#     sen_token =[]
    sen = []
    sen_s = []
    sen_t = []
    labelset = []
    for i in range(len(Data)):
        if i >= 0:
#             print i,
            emotion = Data[0][i]
            sit = Data[1][i]
#             if emotion not in ['shame', 'guilt']:
            labels.append(emotion)
            labelset.append([emotion])
            sent = removal(sit)
            nava, sent_pt = pos_tag(sent)
            sentences, sen_string, sen_token = stemming(sent_pt)
            sen.append(sentences)
            sen_s.append(sen_string)
            sen_t.append(sen_token)
#     labels, labelset, exclude = class_labels(emotions[1:])
#     sent = removal(sit[1:], exclude)
#     nava, sent_pt = pos_tag(sent)
#     sentences, sen_string, sen_token = stemming(sent_pt)
    frame = pd.DataFrame({0 : labels,
                          1 : sen,
                          2 : sen_s,
                          3 : sen_t,
                          4 : labelset})
    return frame, sen_t, labels, sen_s

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
c, st, labels, senten = create_frame(Data)

# %%
c
# Out:
#             0                                                  1  \
# 0         joy  (day, feel, close, partner, other, friend, fee...
# 1        fear  (time, imagin, someon, love, contact, seriou, ...
# 2       anger  (had, been, obvious, unjustli, treat, had, pos...
# 3     sadness  (think, short, time, live, relat, period, life...
# 4     disgust  (gather, found, involuntarili, sit, next, peop...
# ...       ...                                                ...
# 7511    shame  (year, back, someon, invit, tutor, grand-daugh...
# 7512    shame  (had, taken, respons, someth, had, prepar, how...
# 7513     fear  (wa, home, heard, loud, sound, spit, door, tho...
# 7514    guilt  (did, not, homework, teacher, had, ask, wa, sc...
# 7515     fear  (had, shout, younger, brother, wa, alway, afra...
#
#                                                       2  \
# 0     day feel close partner other friend feel peac ...
# 1     time imagin someon love contact seriou ill eve...
# 2     had been obvious unjustli treat had possibl el...
# 3     think short time live relat period life think ...
# 4     gather found involuntarili sit next peopl expr...
# ...                                                 ...
# 7511  year back someon invit tutor grand-daught gran...
# 7512  had taken respons someth had prepar howev fail...
# 7513  wa home heard loud sound spit door thought fam...
# 7514  did not homework teacher had ask wa scold immedi
# 7515  had shout younger brother wa alway afraid call...
#
#                                                       3          4
# 0     [day, feel, close, partner, other, friend, fee...      [joy]
# 1     [time, imagin, someon, love, contact, seriou, ...     [fear]
# 2     [had, been, obvious, unjustli, treat, had, pos...    [anger]
# 3     [think, short, time, live, relat, period, life...  [sadness]
# 4     [gather, found, involuntarili, sit, next, peop...  [disgust]
# ...                                                 ...        ...
# 7511  [year, back, someon, invit, tutor, grand-daugh...    [shame]
# 7512  [had, taken, respons, someth, had, prepar, how...    [shame]
# 7513  [wa, home, heard, loud, sound, spit, door, tho...     [fear]
# 7514  [did, not, homework, teacher, had, ask, wa, sc...    [guilt]
# 7515  [had, shout, younger, brother, wa, alway, afra...     [fear]
#
# [7516 rows x 5 columns]

# %%
'''
Reads the emotion representative words file
'''
def readfile(filename):
    f = open(filename,'r')
    representative_words = []
    for line in f.readlines():
        characters = ["\n", " ", "\r", "\t"]
        new = ''.join([i for i in line if not [e for e in characters if e in i]])
        representative_words.append(new)
    return representative_words

# %%
'''
Makes a list of all words semantically related to an emotion and Stemming
'''
def affect_wordlist(words):
    affect_words = []
    stemmer = PorterStemmer()
    for w in words:
        w_l = w.lower()
        word_stem = stemmer.stem(w_l)
        if word_stem not in affect_words:
            affect_words.append(word_stem)
    return affect_words

# %%
'''
Creating an emotion wordnet
'''
def emotion_word_set(emotions):
    word_set = {}
    for e in emotions:
        representative_words = readfile(e)
        wordlist = affect_wordlist(representative_words)
        word_set[e] = wordlist
    return word_set

# %%
'''
Emotion Detector
'''
# c = create_frame(Data)
# emo_word_net = emotion_word_set(emotion_set)
# Out:
# '\nEmotion Detector\n'

# %%
'''
Getting synonyms from wordnet synsets
'''
def get_synonyms():
    syn = {}
    for e in emotion_labels:
        jw = wn.synsets(e)
        for s in jw:
            v = s.name()
            try:
                syn[e].append(wn.synset(v).lemma_names())
            except KeyError:
                syn[e] = wn.synset(v).lemma_names()

# %%
'''
Creating training/testing set for Naive Bayes classifier TextBlob -- Not used
'''
def create_dataset_textblob(sentences, emotions):
    train = []
    sen = []
    emo = []
    for s in sentences:
        sen.append(s)
    for e in emotions:
        emo.append(e)
    for i in range(len(sen)):
        s = sen[i]
        e = emo[i]
        train.append((str(s), e))
    return train

# %%
'''
Testing for Naive Bayes Classifier
'''
def testing(cl, test):
    for s, e in test:
        r = cl.classify(s)
        print(s, e, r)
        if r == e:
            print("*")

# %%
'''
Create dataset for nltk Naive Bayes
'''
def create_data(sentence, emotion):
    data = []
    for i in range(len(sentence)):
        sen = []
        for s in sentence[i]:
            sen.append(str(s))
        emo = emotion[i]
        data.append((sen, emo))
    return data

# %%
'''
Get all words in dataset
'''
def get_words_in_dataset(dataset):
    all_words = []
    for (words, sentiment) in dataset:
        all_words.extend(words)
    return all_words

# %%
'''
Getting frequency dist of words
'''
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
'''
Extacting features
'''
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
'''
Create test data
'''
def create_test(sentence, emotion):
    data = []
    sen = []
    emo = []
    for s in sentence:
        sen.append(str(s))
    for e in emotion:
        emo.append(e)
    for i in range(len(sen)):
        temp = []
        temp.append(sen[i])
        temp.append(emo[i])
        data.append(temp)
    return data

# %%
'''
Classifier
'''
def classify_dataset(data):
    return \
        classifier.classify(extract_features(nltk.word_tokenize(data)))

# %%
'''
Get accuracy
'''
def get_accuracy(test_data, classifier):
    total = accuracy = float(len(test_data))
    for data in test_data:
       # if classify_dataset(data[0]) == data[1]:
             print(data, classify_dataset(data[0]), data[1])
             accuracy -= 1
    print('Total accuracy: %f%% (%d/20).' % (accuracy / total * 100, accuracy))
    final = accuracy / total * 100
    return final

# %%
# Create training and testing data
sen = c[3]
emo = c[0]
l = len(c[3])
limit = (9*l)//10
sente = c[2]
Data = create_data(sen[:limit], emo[:limit])
test_data = create_test(sente[limit:], emo[limit:])

# %%
# extract the word features out from the training data
word_features = get_word_features(\
                    get_words_in_dataset(Data))

# %%
# get the training set and train the Naive Bayes Classifier
training_set = nltk.classify.util.apply_features(extract_features, Data)
classifier = NaiveBayesClassifier.train(training_set)

# %%
get_accuracy(test_data, classifier)
# Out:
# ['scoar goal footbal match ', 'joy'] joy joy
# ['left alon dark big build ', 'fear'] fear fear
# ['someon call disgust nicknam ', 'disgust'] disgust disgust
# ['not get someon classmat high school ', 'sadness'] sadness sadness
# ['woman pick nose spit right next ', 'disgust'] disgust disgust
# ['not brave enough take challeng group discuss ', 'shame'] shame shame
# ['not be good host friend far away place ', 'guilt'] joy guilt
# ['class win class footbal match ', 'joy'] joy joy
# ['walk alon dark strang street ', 'fear'] fear fear
# ['friend forgot appoint ', 'guilt'] guilt guilt
# ['friend misunderstood ', 'sadness'] sadness sadness
# ['boy class talk too loud lectur ', 'shame'] shame shame
# ['not be abl have parti home friend ', 'shame'] shame shame
# ['be miser parti other peopl are friendli happi ', 'joy'] joy joy
# ['meet old friend high school ', 'joy'] joy joy
# ['face mad dog ', 'fear'] fear fear
# ['misunderstood deliber close friend ', 'sadness'] sadness sadness
# ['old teacher primari school die ', 'sadness'] sadness sadness
# ['get crowd bu ', 'disgust'] disgust disgust
# ['be rude somebodi wa impolit ', 'anger'] anger anger
# ['not accept hint intim relat girl ', 'sadness'] sadness sadness
# ['old friend visit univers ', 'joy'] joy joy
# ['listen horrot stori night ', 'fear'] disgust fear
# ['roommat wa rude ', 'anger'] anger anger
# ['uncl die vietnam war ', 'sadness'] sadness sadness
# ['cue student dine hall ', 'disgust'] disgust disgust
# ['argu price privat shop-assist ', 'anger'] anger anger
# ['not be abl spend more time friend wa visit ', 'guilt'] guilt guilt
# ['score goal footbal match ', 'joy'] joy joy
# ['find not abl student thought ', 'fear'] sadness fear
# ['wa told someth did not want ', 'anger'] guilt anger
# ['find china still backward scienc ', 'sadness'] joy sadness
# ['do pointless questionnair ', 'anger'] anger anger
# ['insult somebodi ', 'disgust'] disgust disgust
# ['not do questionnair ', 'anger'] anger anger
# ['saw china had most gold medal asian olymp ', 'anger'] anger anger
# ['just arriv univers not know anybodi ', 'fear'] shame fear
# ['insult teacher ', 'shame'] shame shame
# ['find not good look ', 'sadness'] sadness sadness
# ['someon not kept talk ', 'anger'] anger anger
# ['find lectur china backward psycholog ', 'shame'] joy shame
# ['be rude someon not ', 'anger'] anger anger
# ['join research group studi consum behaviour help peopl shop sale ', 'joy'] disgust joy
# ['diagnosi have stomach ulcer ', 'sadness'] sadness sadness
# ['classmat damag iron tri hide damag ', 'anger'] anger anger
# ['not win medal swim contest ', 'sadness'] joy sadness
# ['student talk other peopl are have nap ', 'disgust'] disgust disgust
# ['friend ask help wa not abl help ', 'guilt'] guilt guilt
# ['china win asian olymp ', 'joy'] joy joy
# ['exam ', 'fear'] joy fear
# ['korean judg cheat ', 'shame'] shame shame
# ['father left woman ', 'sadness'] sadness sadness
# ['saw father woman marri now ', 'disgust'] disgust disgust
# ['had tell peopl parent are divorc ', 'shame'] shame shame
# ['not bee abl stay mother nation day holiday ', 'guilt'] guilt guilt
# ['be togeth best friend ', 'joy'] sadness joy
# ['almost had bicycl accid ', 'fear'] fear fear
# ['heard someon tell lie best friend ', 'sadness'] sadness sadness
# ['best friend suddenli act strang toward ', 'disgust'] disgust disgust
# ['saw someon mess room ', 'disgust'] disgust disgust
# ['shout friend ', 'sadness'] sadness sadness
# ['did not promis friend ', 'guilt'] guilt guilt
# ['best friend chosen english lectur ', 'joy'] joy joy
# ['get ill ', 'sadness'] sadness sadness
# ["class leader told univers n't let lectur are not english class ", 'anger'] anger anger
# ['wa not chosen english lectur ', 'sadness'] shame sadness
# ['find class leader lectur english wors mine ', 'sadness'] anger sadness
# ['china not let give more lectur are need specialist clinic are backward medicin ', 'shame'] shame shame
# ['hate not let found wa not decis ', 'guilt'] anger guilt
# ['find best friend not english lectur ', 'sadness'] sadness sadness
# ['heard postgradu student talk girl be unsiut medicin ', 'disgust'] joy disgust
# ['fail exam ', 'sadness'] joy sadness
# ['not be abl convinc class leader friend better english lectur ', 'shame'] shame shame
# ['receiv letter boy care ', 'joy'] joy joy
# ['watch horror film ', 'fear'] disgust fear
# ['parent not friend told not ', 'sadness'] sadness sadness
# ['grandmoth die ', 'sadness'] sadness sadness
# ['saw someon spit public ', 'disgust'] disgust disgust
# ['fail examn lazy ', 'sadness'] sadness sadness
# ['lose temper sister ', 'sadness'] sadness sadness
# ['find english lectur ', 'joy'] sadness joy
# ['stay alon dark place ', 'fear'] fear fear
# ['be sexual assult bu ', 'disgust'] disgust disgust
# ['find best friend not univers ', 'sadness'] sadness sadness
# ['boy not cue dine hall ', 'disgust'] disgust disgust
# ['watch china win gold medal ', 'joy'] joy joy
# ['not be abl help friend homework ', 'guilt'] guilt guilt
# ['get univers ', 'joy'] joy joy
# ['beaten classmat school ', 'disgust'] disgust disgust
# ['be insult public ', 'shame'] shame shame
# ['girl love doe not love ', 'sadness'] sadness sadness
# ['saw girl dress american ', 'disgust'] disgust disgust
# ['fail univers entranc examn ', 'shame'] joy shame
# ['not hand homework time ', 'shame'] shame shame
# ['get univers medicin ', 'joy'] joy joy
# ['first time anatomi ', 'fear'] joy fear
# ['misunderstood close friend wrong reason ', 'guilt'] guilt guilt
# ['find china poor not have good refer book ', 'sadness'] shame sadness
# ['foreign student play loud music night biolog examn ', 'shame'] shame shame
# ['find univers polic wa afraid stop foreign student play loud music china shame ', 'shame'] shame shame
# ['not do well examn ', 'shame'] shame shame
# ['aticl publish ', 'joy'] joy joy
# ['earth crake ', 'joy'] joy joy
# ['made statement other peopl did not believ ', 'anger'] shame anger
# ['saw poverti countrysid ', 'shame'] disgust shame
# ['saw chines peopl flatter foreign ', 'disgust'] disgust disgust
# ['not be abl argu class leader ', 'guilt'] guilt guilt
# ['not help student need help ', 'guilt'] guilt guilt
# ['china win asian olymp game ', 'joy'] joy joy
# ['stay alon dark ', 'fear'] fear fear
# ['be put class leader ', 'anger'] anger anger
# ['find life span china shorter west ', 'sadness'] sadness sadness
# ['girl dress foreign univers ', 'disgust'] joy disgust
# ['be insult public ', 'shame'] shame shame
# ['insult other peopl ', 'disgust'] disgust disgust
# ['found travel best friend ', 'joy'] sadness joy
# ['walk home dark colleg ', 'fear'] fear fear
# ['find wa deceiv friend ', 'anger'] anger anger
# ['not do well examn ', 'shame'] shame shame
# ['find best friend wa deceiv ', 'anger'] anger anger
# ['fail examn did not work hard enough ', 'guilt'] guilt guilt
# ['not act promis ', 'shame'] shame shame
# ['find not ill not serious ', 'joy'] sadness joy
# ['find health condit attend univers lectur ', 'fear'] joy fear
# ['bought someth bad shop refus chang ', 'anger'] guilt anger
# ['rel death ', 'sadness'] sadness sadness
# ['saw peopl quarrel bu ', 'disgust'] disgust disgust
# ['run away fire ', 'sadness'] sadness sadness
# ['forgot give present littl nephew ', 'guilt'] guilt guilt
# ['first public speak ', 'joy'] shame joy
# ['go alon dark ', 'fear'] fear fear
# ['saw young peopl fight seat bu ', 'disgust'] disgust disgust
# ['mother death ', 'sadness'] sadness sadness
# ['saw peopl spit public ', 'disgust'] disgust disgust
# ['went lectur chines histori hear opium war ', 'shame'] joy shame
# ['fall love ', 'joy'] joy joy
# ['friend find love ', 'sadness'] sadness sadness
# ['fall love friend angri ', 'anger'] anger anger
# ['friend still trust friend ', 'sadness'] joy sadness
# ['someon be arrog ', 'disgust'] joy disgust
# ['insult teacher front class ', 'shame'] shame shame
# ['fall love close friend ', 'sadness'] sadness sadness
# ['do unexpectedli well examn ', 'joy'] joy joy
# ['examn ', 'joy'] joy joy
# ['want borrow lectur note friend did not lend ', 'guilt'] guilt guilt
# ['find univers doe not have enough foreign currenc buy yournal refer list ', 'anger'] anger anger
# ['someon told wa chosen english lectur wa good friend class leader ', 'shame'] shame shame
# ['find chines money not buy foreign journal ', 'anger'] anger anger
# ['late lectur therefor miss ', 'guilt'] guilt guilt
# ['talk close friend ', 'joy'] sadness joy
# ['ran park car bicycl ', 'fear'] fear fear
# ['insult reason ', 'shame'] shame shame
# ['did badli examn ', 'sadness'] sadness sadness
# ['saw man dress woman ', 'disgust'] disgust disgust
# ['saw beggar street china still poor ', 'disgust'] disgust disgust
# ['not buy refer book got too late cue ', 'guilt'] guilt guilt
# ['found best friend are chosen english lectur ', 'joy'] shame joy
# ['not clever enough understand english lectur ', 'shame'] shame shame
# ['told peopl class leader onli choos friend not true ', 'anger'] anger anger
# ['best friend wa hurt girl love ', 'sadness'] sadness sadness
# ['saw veri arrog girl walk queen ', 'disgust'] joy disgust
# ['china not buy refer ', 'shame'] shame shame
# ['friend ask borrow note did not give away note too badli written ', 'guilt'] guilt guilt
# ['talk close friend ', 'joy'] sadness joy
# ['get ill ', 'sadness'] sadness sadness
# ['fail elect class leader ', 'shame'] shame shame
# ['father lost temper home wa mistreat work ', 'anger'] anger anger
# ['saw someon pick cigarett floor smoke ', 'disgust'] disgust disgust
# ['tell lie ', 'shame'] shame shame
# ['not get class paper time lectur ', 'shame'] shame shame
# ['father promot professor ', 'joy'] shame joy
# ['anatomi lesson told have night sometim ', 'fear'] fear fear
# ['had argument classmat borrow book ', 'guilt'] guilt guilt
# ['find not have good refer china poor ', 'shame'] shame shame
# ['saw someon lick dine bowl ', 'disgust'] disgust disgust
# ['critic front class ', 'shame'] shame shame
# ['not finish homework time ', 'shame'] shame shame
# ['found girl love love too ', 'joy'] shame joy
# ['read horror stori alon ', 'fear'] fear fear
# ['be refus attend neuropsycholog lectur medic univers ', 'anger'] joy anger
# ['parent told not friend ', 'sadness'] sadness sadness
# ['saw arrog girl walk pass ', 'disgust'] joy disgust
# ['not finish duti class leader ', 'anger'] anger anger
# ['friend had troubl wa not abl help ', 'guilt'] guilt guilt
# ['china win asian olymp game ', 'joy'] joy joy
# ['left alon biolog build surround empti build ', 'fear'] fear fear
# ['someon told are not good all english class ', 'shame'] shame shame
# ['not get refer paper ', 'shame'] shame shame
# ['cue bu driver have long dinner ', 'disgust'] disgust disgust
# ['not finish homework ', 'shame'] shame shame
# ['did not return librari book time ', 'guilt'] guilt guilt
# ['veri nice joke made friend ', 'joy'] joy joy
# ['think death walk alon night ', 'fear'] fear fear
# ['found someon knew well ha been misunderstand year ', 'shame'] shame shame
# ['death rel ', 'sadness'] sadness sadness
# ['someon know respect sexual assult girl ', 'shame'] shame shame
# ['father insult other peopl ', 'disgust'] disgust disgust
# ['made mistak work ', 'anger'] anger anger
# ['name list attend english lectur ', 'joy'] joy joy
# ['do alon first time ', 'joy'] joy joy
# ['be insult front parent believ other peopl insult ', 'shame'] shame shame
# ['death gener jiani ', 'sadness'] sadness sadness
# ['someon had stolen articl librari journal ', 'disgust'] anger disgust
# ['not do well examn ', 'shame'] shame shame
# ['not finish homework time ', 'guilt'] shame guilt
# ['did well examn just father birthday best present give father ', 'joy'] joy joy
# ['ask someon bring present father found not reliabl person wa afraid father not get present angri ', 'fear'] guilt fear
# ['classmat said did not enough social work therefor wa not elect tree good student ', 'anger'] guilt anger
# ["father n't pleas wa elect good ", 'sadness'] joy sadness
# ['roommat lack consider ', 'disgust'] anger disgust
# ['sister said not stabl person think right ', 'shame'] guilt shame
# ['sister forgot bring present birthday wa rude ', 'guilt'] guilt guilt
# ['had nice letter close friend ', 'joy'] joy joy
# ['stay alon biolog build dark ', 'fear'] fear fear
# ['be insult roommat english class ', 'anger'] anger anger
# ['not be abl well chosen english lectur ', 'sadness'] shame sadness
# ['roommat boast english lectur ', 'disgust'] anger disgust
# ['class leader read name chosen english lectur wa not list ', 'shame'] shame shame
# ['boy told nicknam littl girl doctor did not tell laugh ', 'guilt'] shame guilt
# ['rel visit ', 'joy'] sadness joy
# ['find great differ china west scienc ', 'fear'] joy fear
# ['saw unfair report ', 'disgust'] disgust disgust
# ['lectur be unfair report ', 'disgust'] disgust disgust
# ['find student are get good report not deserv ', 'anger'] anger anger
# ['peopl impolit did not get good report ', 'anger'] anger anger
# ['kick chair classroom express anger ', 'anger'] anger anger
# ['find wa chosen english lectur ', 'joy'] joy joy
# ['roommat refus walk english lectur have walk alon dark lectur are biolog build ', 'fear'] fear fear
# ['roommat be unconsider ', 'anger'] anger anger
# ['best friend wa not chosen english lectur ', 'shame'] shame shame
# ['someon told wa chosen english lectur good look ', 'shame'] shame shame
# ['not do well examn ', 'shame'] shame shame
# ['boy talk nicknam lectur wa too afraid stop ', 'fear'] fear fear
# ['found wife pregnant ', 'joy'] sadness joy
# ['boat run boat ', 'joy'] joy joy
# ['punish leader ', 'anger'] anger anger
# ['teacher death ', 'sadness'] sadness sadness
# ['saw mate bribe leader ', 'disgust'] disgust disgust
# ['insult woman public ', 'shame'] shame shame
# ['fight mate quarrel ', 'disgust'] disgust disgust
# ['receiv nice present parent ', 'joy'] joy joy
# ['find made stupid mistak examn ', 'anger'] anger anger
# ['find girl have been nice class leader order neuropsycholog lectur english one ', 'anger'] disgust anger
# ['find not chosen english lectur ', 'shame'] shame shame
# ['student english wors mine lectur english lectur ', 'sadness'] sadness sadness
# ['insult classmat public ', 'shame'] shame shame
# ['not hand homework time ', 'shame'] shame shame
# ['articl publish ', 'joy'] joy joy
# ['walk dark think ghost stori ', 'fear'] fear fear
# ['had insult letter father ', 'shame'] shame shame
# ['be misunderstood friend ', 'sadness'] sadness sadness
# ['saw someon act fals manner public ', 'disgust'] disgust disgust
# ['fail piblic argument ', 'shame'] sadness shame
# ['promis someth other peopl did not ', 'guilt'] shame guilt
# ['find chosen collect norm chines aphasia contribut china catch west neuropsycholog ', 'joy'] joy joy
# ['find lectur doctor make misdiagnos ignor neuropsycholog ', 'fear'] disgust fear
# ['someon talk back ', 'anger'] anger anger
# ['found grandmoth have been misdiagnos psychiatr patient doctor did not know neurolog ', 'sadness'] sadness sadness
# ['student deliber disobey class leader ', 'disgust'] anger disgust
# ['find china backward scienc ', 'shame'] joy shame
# ['student have been call lectur nicknam wa not abl find were stop ', 'guilt'] anger guilt
# ['go concert ', 'joy'] joy joy
# ['find boy not like love ', 'fear'] sadness fear
# ['be told have not got person ', 'anger'] guilt anger
# ['power cut made unabl listen song sung favourit pop star ', 'sadness'] disgust sadness
# ['someon act stupid public ', 'disgust'] shame disgust
# ['not be abl answer question seminar ', 'shame'] shame shame
# ['said someth not have said public ', 'guilt'] shame guilt
# ['talk close friend ', 'joy'] sadness joy
# ['hear strang nois biolog build ', 'fear'] fear fear
# ['insult other peopl shop ', 'anger'] disgust anger
# ['good friend misunderstood ', 'sadness'] sadness sadness
# ['be look someon not ', 'disgust'] shame disgust
# ['chosen english lectur instead good friend peopl told girl are more like chosen ', 'shame'] shame shame
# ['wa not abl explain well good friend make less angri ', 'guilt'] anger guilt
# ['find person love understand ', 'joy'] sadness joy
# ['watch horror film ', 'fear'] disgust fear
# ['be mistreat other peopl ', 'anger'] disgust anger
# ['deceiv other peopl ran troubl ', 'sadness'] shame sadness
# ['saw selfish person do selfish thing ', 'disgust'] disgust disgust
# ['not do well examn ', 'shame'] shame shame
# ['find have misunderstood other peopl ', 'guilt'] anger guilt
# ['hear name list attend english lectur ', 'joy'] joy joy
# ['stay alon room midnight read horror stori ', 'fear'] fear fear
# ['be told stupid person ', 'anger'] anger anger
# ['parent fail visit promis ', 'sadness'] guilt sadness
# ['peopl not cue dine hall ', 'disgust'] disgust disgust
# ['saw china not win more gold medal asian olymp ', 'shame'] anger shame
# ['not hand homework time ', 'guilt'] shame guilt
# ['have good trip boat good friend ', 'joy'] joy joy
# ['saw classmat knock down motorcycl ', 'fear'] disgust fear
# ['be sexual assult bu noon help peopl onli laugh ', 'anger'] shame anger
# ['be sexual assult told friend cri togeth ', 'sadness'] guilt sadness
# ['heard someon boast fortun tell knew wa lie ', 'disgust'] shame disgust
# ['be critic teacher public ', 'shame'] shame shame
# ['shout parent wa angri someth els ', 'guilt'] guilt guilt
# ['go see good film best friend ', 'joy'] joy joy
# ['suddenli found wa lasr leav anatomi room ', 'fear'] fear fear
# ['boy deliber play trick experi ', 'anger'] anger anger
# ['iqam chosen lectur best friend not now angri not help ', 'sadness'] anger sadness
# ['listen roommat boast new cloth ', 'disgust'] anger disgust
# ['china not win more gold medal asian olymp ', 'shame'] anger shame
# ['not be abl help friend studi english ', 'guilt'] sadness guilt
# ['be elect class leader ', 'joy'] joy joy
# ['walk dark saw someth strang ', 'fear'] fear fear
# ['prejudic psycholog student educ student not allow medic univers lectur ', 'anger'] joy anger
# ['friend brother die ', 'sadness'] sadness sadness
# ['wurm drop head ', 'disgust'] disgust disgust
# ['not do well examn wa easi ', 'shame'] shame shame
# ['wrongli accus classmat ', 'guilt'] anger guilt
# ['get univers medicin ', 'joy'] joy joy
# ['first time anatomi ', 'fear'] joy fear
# ['be insult public wrong reason ', 'anger'] shame anger
# ['not be chosen english lectur girl-friend chosen ', 'sadness'] shame sadness
# ['roommat mess room ', 'disgust'] anger disgust
# ['not do well examn well english examn ', 'shame'] shame shame
# ['heard girl-friend wa chosen english lectur wa not lost temper veri upset now ', 'guilt'] sadness guilt
# ['success univers entranc examin ', 'joy'] joy joy
# ['help someon someth wa found ', 'fear'] guilt fear
# ['misunderstood friend ', 'anger'] sadness anger
# ['mother wa ill father wa not home ', 'sadness'] sadness sadness
# ['roommat be nice parti leader order get parti ', 'disgust'] disgust disgust
# ['china not do well asian olymp game ', 'shame'] joy shame
# ['not collect letter friend promis ', 'guilt'] guilt guilt
# ['do well examn ', 'joy'] joy joy
# ['examn ', 'fear'] joy fear
# ['foreign student play loud music biolog examn ', 'anger'] shame anger
# ['find girl like doe not ', 'sadness'] sadness sadness
# ['saw canadian student boast rich are canada ', 'disgust'] disgust disgust
# ['find china doe not have enough foreign currenc buy book ', 'shame'] anger shame
# ['call lectur nicknam talk housemen told are even younger are not give public lectur ', 'guilt'] shame guilt
# ['had letter father usual doe not write ', 'joy'] anger joy
# ['be alon room night ', 'fear'] fear fear
# ['quarrel classmat ', 'anger'] disgust anger
# ['father told letter mother ill ', 'sadness'] sadness sadness
# ['roommat talk shake bed night ', 'disgust'] fear disgust
# ['find wa deceiv friend ', 'shame'] anger shame
# ['friend came visit wa not there ', 'guilt'] sadness guilt
# ['find name list english lectur ', 'joy'] joy joy
# ['walk biolog build ', 'fear'] fear fear
# ['someon told wa chosen english lectur class leader go not true ', 'anger'] anger anger
# ['sister bkoke leg ', 'sadness'] sadness sadness
# ['boy boast abil tell dirti joke ', 'disgust'] disgust disgust
# ['find china backward scienc ', 'shame'] joy shame
# ['housemen told young girl not allow lectur consult wa too shi argu ', 'guilt'] guilt guilt
# ['made wonder driend understand ', 'joy'] joy joy
# ['be chase dark someon did not know ', 'fear'] fear fear
# ['best friend betray told other peopl secret ', 'anger'] shame anger
# ['disappoint friend ', 'sadness'] sadness sadness
# ['find peopl had been talk back ', 'disgust'] anger disgust
# ['be sexual assult public ', 'shame'] shame shame
# ['did not repli friend letter time ', 'guilt'] joy guilt
# ['watch china win asian olymp game ', 'joy'] joy joy
# ['suddenli met someon biolog build night ', 'fear'] fear fear
# ['be insult roommat ', 'anger'] anger anger
# ['not get airplan ticket fot mother ', 'guilt'] guilt guilt
# ['talk nice girl ', 'joy'] joy joy
# ['talk snake ', 'fear'] disgust fear
# ['peopl not resprct opinion ', 'anger'] anger anger
# ['lost girl-friend ', 'sadness'] sadness sadness
# ['talk someon dislik ', 'disgust'] disgust disgust
# ['critic teacher public ', 'shame'] shame shame
# ['not be abl help friend ', 'guilt'] guilt guilt
# ['get letter friend did not write long time ', 'joy'] joy joy
# ['stay rel hous wa broken ', 'fear'] fear fear
# ['be insult bu ', 'anger'] disgust anger
# ['insult mother ', 'sadness'] shame sadness
# ['rel not act promis ', 'disgust'] guilt disgust
# ['first time go boy other peopl laugh ', 'shame'] shame shame
# ['friend want give surpris room thought wa steal room ', 'guilt'] shame guilt
# ['be ask someon care ', 'joy'] guilt joy
# ['import examn ', 'fear'] joy fear
# ['parent not friend told stay away ', 'anger'] sadness anger
# ['friend not allow english lectur ', 'sadness'] anger sadness
# ['postgradu student talk girl stupid ', 'disgust'] disgust disgust
# ['ctitic teacher public ', 'shame'] shame shame
# ['friend did not well examn did not help ', 'guilt'] shame guilt
# ['went picnic countri side beauti scenari made feel relax worri disappear thu picnic wa worthwhil ', 'joy'] joy joy
# ['afraid academ result face sever problem scare limit unlimit problem not know cope ', 'fear'] fear fear
# ['quarrel brother twin home saturday studi privat school other repeat form not know are do follow word teacher book system alway tri ration bad act game are satisfi awkward life have tri persuad veri often have fail time had fight have voluntari spirit did not polish floor ', 'anger'] shame anger
# ['have been think chang major few month origin major wa chines languag block way have face mani problem sametim not know real virtuou not know not interest chines are other factor make sad not veri clear studi commun journal not clear are limit hesit feel more adjust now ', 'sadness'] anger sadness
# ['had been forc get togeth strang disgust classmat thing talk disgust made feel ill eas knew feel unhappi stay wa defeat social norm ', 'disgust'] disgust disgust
# ['had obvious done work badli class-mat student associ did not blame help work ', 'shame'] anger shame
# ['had not done assign serious onli pretend finish work work did not have mean whole thing made feel guilti ', 'guilt'] guilt guilt
# ['preach f.3 student gospel camp thu knew more god made mind believ jesu ', 'joy'] joy joy
# ['doctor told wa someth wrong eye had undergo oper ', 'fear'] guilt fear
# ['had left student newspap chines univers tabl librari had disappear came back ', 'anger'] joy anger
# ['class-mat had diseas unexpectedli had been coma day hospit die ', 'sadness'] sadness sadness
# ['someon wa sit veri close wa smoknig compart air condit mini-bu ', 'disgust'] fear disgust
# ['compart public transport railway did not give seat old man wa stand wa teenag did ', 'shame'] disgust shame
# ['saturday night did meaningless work went bed veri late next morn had wa veri sleepi continu sleep even had work miss sunday servic ', 'guilt'] guilt guilt
# ['attend concert pop singer ', 'joy'] joy joy
# ['wa afraid fail examin ', 'fear'] fear fear
# ['had too much homework examin did not know organ work ', 'anger'] shame anger
# ['forgot lyric song contest ', 'sadness'] joy sadness
# ['examin had studi night day ', 'disgust'] joy disgust
# ['did badli mid term examin ', 'shame'] sadness shame
# ['result mid term examin were veri poor ', 'guilt'] joy guilt
# ['had good result certif examin ', 'joy'] joy joy
# ['wa walk road alon way shop ', 'fear'] fear fear
# ['student union there wa someon took photocopi larg volum ask let take few refus accept reason ', 'anger'] anger anger
# ['person mother die ', 'sadness'] sadness sadness
# ['greet friend did not respond ', 'disgust'] shame disgust
# ['examin other student easi hardli think did not know answer ', 'shame'] shame shame
# ['cut friend hair anger consider ', 'guilt'] anger guilt
# ['yesterday friend gave gift had dinner ', 'joy'] joy joy
# ['onc walk hill fell down out careless broke left arm ', 'fear'] fear fear
# ['last week organ summon execut meet execut member point loop hole committe administr not suggest improv quarrel ', 'anger'] guilt anger
# ['death father ', 'sadness'] sadness sadness
# ['wa sit bu man veri unpleas smell came sat next top smoke contin ', 'disgust'] disgust disgust
# ['wa canteen unit colleg mistook stranger classmat wa not wear glass realiz had made mistak saw again care ', 'shame'] shame shame
# ['got late not lesson time enter class room stare teacher classmat made feel guilti ', 'guilt'] shame guilt
# ['applic studi master degre wa accept ', 'joy'] joy joy
# ['onc midnight wa work alon offic phone suddenli rang ', 'fear'] fear fear
# ['wa concentr work friend disturb contin ask stop vain ', 'anger'] anger anger
# ['had ask teacher write recommend letter had not provid enough inform had run short time ', 'sadness'] shame sadness
# ['wa talk person hypocrit felt disgust reaction ', 'disgust'] disgust disgust
# ['companion admir did work voluntarili ', 'shame'] joy shame
# ['wrong behaviour made love feel sad uneasi ', 'guilt'] guilt guilt
# ['first heard like boyfriend ', 'joy'] joy joy
# ['receiv higher level result mistook grade mathemat grade wa shock ', 'fear'] joy fear
# ['had plan studi mid-term exam certain day room-mat call ask stroll tri make excus not refus listen insist find unnecessari talk anymor ', 'anger'] anger anger
# ['due reason boyfriend decid separ ', 'sadness'] sadness sadness
# ['onc had start write paper wa phone call had downstair receiv convers discov inform had disappear mind ', 'disgust'] shame disgust
# ['teacher ask question did not know answer just stood still few minut say word ', 'shame'] shame shame
# ['onc wa cell group religi activ found almost everyon group read bibl daili felt guilti heart ', 'guilt'] guilt guilt
# ['read newspap morn found candidatur number admiss list chines univers wa satisfi happi cumul anxieti disappear onli want cri had succeed ', 'joy'] joy joy
# ['tutori again fear feel came sat chair look fellow student wa realli scare ask question challeng idea had present ', 'fear'] fear fear
# ['trick wa realli intoler hid wa worri restless day saw realli want slap ', 'anger'] shame anger
# ['were walk along new asia stairway chung chi colleg lectur saw put arm shoulder laugher brightli joy did not dare did not want look just walk quickli interest talk disappear just want remain silent did not want know left went have expect happen ', 'sadness'] fear sadness
# ['know had survey felt veri reluct not know feel disgust just look think project last sever day regret have join project ', 'disgust'] sadness disgust
# ['lesson teacher call ask had report wa late pretend had look eye knew knew wa lie thought wa realli bad luck had examin list student were late ', 'shame'] shame shame
# ['even open songbook wa sing song were day guilt feel becam stronger lyric describ well wa realli wrong wish had made wa realli bad were realli happi play happili togeth day secondari school not disappoint gloomi ', 'guilt'] guilt guilt
# ['learnt further studi chines univers ', 'joy'] joy joy
# ['best frieend left school recent next day weather turn bad suddenli male class-mat turn light remain tabl wa scare ', 'fear'] fear fear
# ['wa scold mother reason ', 'anger'] guilt anger
# ['learnt had been betray friend ', 'sadness'] joy sadness
# ['dine new friend kept remind wa superior ', 'disgust'] anger disgust
# ['dine accquaint wa ask someth have known did not know ', 'shame'] guilt shame
# ['friend came concert sake wa had organ concert wa unsuccess ', 'guilt'] joy guilt
# ['wa accept chines univers ', 'joy'] joy joy
# ['wait result high level examin wa afraid not be accept ', 'fear'] joy fear
# ['had date friend see movi friend wa late wait long hour wa veri angri ', 'anger'] anger anger
# ['quarrel parent ', 'sadness'] guilt sadness
# ['chines lesson student often show moreov misbehav dress veri badli disgust ', 'disgust'] disgust disgust
# ['saw bag street just then stranger pass pick bag immedi gave stranger thought belong wa not bag felt asham ', 'shame'] shame shame
# ['refus lend homework friend ', 'guilt'] shame guilt
# ['onc had learnt swim step slipperi slope wa lot moss slip water water wa veri deep not stand feet sank had use lot energi ', 'fear'] fear fear
# ['day wa sit not veri crowd bu middl age woman wa stand person sit next got get woman push occupi seat then took shoe put feet seat ', 'disgust'] fear disgust
# ['saw horribl movi alien ', 'fear'] disgust fear
# ['result univers entranc exam were veri poor far had expect thought not accept univers ', 'sadness'] joy sadness
# ['disgust peopl spoil ident misbehaviour morn wa crowd bu found seat univers student wa sit side had put bag file wa veri littl space left sat down kept read even lean did not put bag away did not respond felt veri angri ', 'disgust'] disgust disgust
# ['lectur student includ were ask leav class had not prepar lesson felt asham angri ', 'shame'] shame shame
# ['even went fish friend not fish fisherman had alreadi put net pull net find onli crab threw net away net wa larg have cost fisherman use net earn live had had thrown ', 'guilt'] anger guilt
# ['had veri close friend went canada f.b departur wa unavoid came back summer holiday wa veri happi noth had chang ', 'joy'] sadness joy
# ['day univers result came wa excit scare fail did not know did not want work famili wa ambival ', 'fear'] guilt fear
# ['certif examin wa veri poor biolog worst result class ever f.5 had been get poorer poorer had tri best had spent most time studi subject final result were bad thought wa just not fair ', 'anger'] joy anger
# ['cat die ill had been year wa love cat had been ill week veterinari surgeon had told wa die ', 'sadness'] sadness sadness
# ['secondari school had class-mat talk too much went cinema school sat next comment movi veri disgust ', 'disgust'] disgust disgust
# ['teacher had invit lunch onc canteen start introduc boy show lot interest know person detail then start talk activ held colleg had littl interest activ talk student sit next wa afraid ask question activ ', 'shame'] shame shame
# ['younger sister want take class learn music instrument saturday morn mother ask registr did not want said mani bad peopl club resullt sister wa scold mother ', 'guilt'] anger guilt
# ['studi univers ', 'joy'] joy joy
# ['forgot line play orient camp ', 'fear'] shame fear
# ['depart meet friend ate dish had prepar meet ', 'anger'] shame anger
# ['had veri short term romanc summer vacat first met felt excit want avoid had met few time propos stay apart felt veri sad then ', 'sadness'] joy sadness
# ['felt disgust see boyfriend separ day wa beg mass transit railway station moment hate ', 'disgust'] disgust disgust
# ['act play orient camp made feel timid ', 'shame'] shame shame
# ['made boyfriend unhappi depress feel guilti ', 'guilt'] guilt guilt
# ['friend had organ birthday parti secretli wa veri happi not much present seem care ', 'joy'] joy joy
# ['year old grandfath underw success oper singl year third oper wa riski wa scare die fear grandmoth veri sad ', 'fear'] sadness fear
# ['elder brother often critic mother cook onc did veri impolit lost temper made veri sad wa veri angri scold ask not interfer wa buis ', 'anger'] guilt anger
# ['night not practis violin famili wa watch t.v light want listen tape wa dark ask brother bring torch howev scold wa angri slam violin floor ', 'anger'] anger anger
# ['mother suffer mental ill night wa not feel well wa sent hospit wa scare die night wa veri sad did not dare close eye ', 'sadness'] sadness sadness
# ['crowd condit live alway quarrel elder brother put t.v volum deafen level not practis piano lesson thu feel home disgust ', 'disgust'] disgust disgust
# ['lost temper mother wa teach felt asham sorri have hurt love mother ', 'shame'] shame shame
# ['felt guilti not have practis piano wast teacher time guidanc ', 'guilt'] guilt guilt
# ['watch footbal match old friend perform team wa veri good team member were full spirit match wa excel time goal wa score felt excit ', 'joy'] joy joy
# ['got midterm exam result result were below averag were lowest wa scare final exam ', 'fear'] joy fear
# ['came back hostel bed wa full newspap dirti cloth room-mat ask wash cloth had time wa respons food share had been eaten ate littl ', 'anger'] disgust anger
# ['sister wa impolit father famili wa have lunch togeth restaur thought parent had been prejud wa extrem thought ', 'sadness'] shame sadness
# ['wa give privat tutori student not concentr wa lazi had not done home work had assign academ level wa veri low wa nuisanc ', 'disgust'] guilt disgust
# ['meet said someth wrong other laugh ', 'shame'] shame shame
# ['enter hostel year mother wa ill not move need peopl look everi week left home back school felt guilti ', 'guilt'] guilt guilt
# ['receiv letter friend wa miss ', 'joy'] joy joy
# ['fear not abl hand book-report time had start work veri late book wa difficult read teacher did not accept work wa hand late ', 'fear'] shame fear
# ['classmat alway borrow note not return time had test wa selfish irrespons delay studi ', 'anger'] guilt anger
# ['found cold had hurt somebodi sincer ', 'sadness'] guilt sadness
# ['wa studi someon disturb ', 'disgust'] sadness disgust
# ['teacher said be univers studet did not have self-in self-control ', 'shame'] guilt shame
# ['took french leav homework ', 'guilt'] sadness guilt
# ['realiz fellow member had grown spiritu wa leader spiritu group had pray did not want burn incens mother forc final mother told discontinu got good result school ', 'joy'] anger joy
# ['look toilet dark place ', 'fear'] fear fear
# ['gave tutori student found wa did not pay attent taught did easi question wrong deliber ', 'anger'] anger anger
# ['saw lot starv peopl t.v news report ', 'sadness'] disgust sadness
# ['neighbour came gossip other parent ', 'disgust'] shame disgust
# ['promis friend return book owner forgot ', 'shame'] guilt shame
# ['saw blue film cinema ', 'guilt'] disgust guilt
# ['saw certif result did not feel veri happi did not realiz had got credit classmat point parent rel prais realiz result were good i.e felt satisfi result wa happi ', 'joy'] joy joy
# ['hour receiv certif result wa veri frighten saw other cri felt veri tens time went fear grew ', 'fear'] joy fear
# ['classmat use person relat get seat subject want also had taken pain help appli did not get select did not like had not told fact earlier not have lie ', 'anger'] anger anger
# ['mother went oper wa not veri seriou wa sad not sleep oper ', 'sadness'] sadness sadness
# ['recent meet mr. show excit overindulg note deliv curios not blame way accquir knowledg wa extrem behaviour e.g alway tri know wa read gain everyth ', 'disgust'] anger disgust
# ['wa do homework home rel came advis help mother house-work ', 'shame'] guilt shame
# ['quarrel brother broke glass door cupboard china doll were scold father break door did not tell door ', 'guilt'] anger guilt
# ['wa admit chines universi ', 'joy'] joy joy
# ['inter-colleg basket-bal match ', 'fear'] joy fear
# ['someth wa stolen ', 'anger'] anger anger
# ['learnt close friend wa go immigr ', 'sadness'] sadness sadness
# ['summer holiday job wa almost ', 'disgust'] joy disgust
# ['meet ', 'shame'] joy shame
# ['fail keep appoint ', 'guilt'] guilt guilt
# ['told girlfriend joke openli frankli ', 'joy'] shame joy
# ['onc cross road wa overcom fear ', 'fear'] fear fear
# ['intim girlfriend told father wa oppos relationship had insult integr ', 'anger'] sadness anger
# ['studi are too demand not cope ', 'sadness'] guilt sadness
# ['behaviour peopl spit everywher ', 'disgust'] disgust disgust
# ['not finish homework time ', 'shame'] shame shame
# ['masturb ', 'guilt'] shame guilt
# ['finish work had plan homework ', 'joy'] guilt joy
# ['wa not prepar exam want sleep night exam ', 'fear'] fear fear
# ['someon play trick ', 'anger'] shame anger
# ['thing made friend rel sad happen ', 'sadness'] sadness sadness
# ['wa narrow dirti passag wa locat market had stand there wait peopl ', 'disgust'] fear disgust
# ['had someth wrong say wrong thing be impolit someon had embarrass person still meet person ', 'shame'] shame shame
# ['said someth wa conscienc ', 'guilt'] shame guilt
# ['sever good friend made surpris visit made happi are closest friend had not seen other long time ', 'joy'] joy joy
# ['hero wa chase terribl vampir suspens horror film shown t.v ', 'fear'] disgust fear
# ['work sever classmat project wa veri anxiou project partner show concern had meet project classmat did not pay attent read book other argu irrelev question meet hour main theme be discuss wast time not reach compromis classmat avoid do work respons seem valu other project more one ', 'anger'] anger anger
# ['good friend had migrat america friendship had develop quit well wa piti friendship fade ', 'sadness'] sadness sadness
# ['studi group person alway like argu unimport irrelev minor point tri persuad other unfriendli way wa obstin not accept other point view ', 'disgust'] anger disgust
# ['onc present wa worst classmat had not prepar well had not seen import present wa confus clearli show poor prepar ', 'shame'] shame shame
# ['joke unfamiliar friend obstin tone wa afraid misunderstand be hurt angri felt sorri conduct thought had find opportun apolog ', 'guilt'] guilt guilt
# ['rememb religi experi gospel camp few friend mine decid believ god joy felt time wa more word express bless prais god heart ', 'joy'] joy joy
# ['friend had offend classmat unintenion want apolog decid visit knew wa stubborn were frighten rang door fear wa climax ', 'fear'] guilt fear
# ['girlfriend dislik play majong game gambl express regret went see neglect exist wa veri angri left displeasur ', 'anger'] anger anger
# ['said good-by girlfriend had spent year develop relationship wa unsuccess felt veri sad ', 'sadness'] sadness sadness
# ['classmat got homework onli got got result act did not merit grade found humil wa hypocrit found disgust ', 'disgust'] disgust disgust
# ['onc primari had forgotten take book class teacher punish ask stand back class thought way mother react saw be punish mother wa veri good did not see punish felt sorri ', 'shame'] guilt shame
# ['had fix meet classmat miss wa tire everyon meet wa stranger did not want make friend reason felt guilti ', 'guilt'] guilt guilt
# ["learnt newspap had been accept chines univers h.k wa o'clock morn later told famili rel had tea veri joy ", 'joy'] joy joy
# ['wa camp old broken hut had light had brought lamp wa not work veri well door made strang sound wa sure strang thing were happen most terrifi bit wa were mani wardrob hut everytim look glass wardrob felt were object whole night wa spent fear restless ', 'fear'] fear fear
# ['footbal match other team wa rude hurt team member coach wa prejud punish unreason later fought other match had cut short ', 'anger'] anger anger
# ['heard death closefriend mine had gone camp shortli death whole thing seem veri sudden ', 'sadness'] sadness sadness
# ['group youngster dress fad talk foul languag bu also insult pedestrian road were impolit passeng bu ', 'disgust'] disgust disgust
# ['christian gather lucki draw mistook girl name mine boy name realiz mistak onli went stage prize did not know everyon wa look blush went back seat ', 'shame'] shame shame
# ['play basketbal broke team member spectacl face wa injur piec glass wa not seriou felt guilti blame be too careless vigor game ', 'guilt'] guilt guilt
# ['busi day went back hostel close door had drink then read favourit book bed suddenli felt peac joy ', 'joy'] shame joy
# ['went home wa nobodi wait till a.m still nobodi wa suddenli scare anxiou had never happen addit mother wa veri weak fear had met accid therefor wa anxiou night ', 'fear'] fear fear
# ['yesterday read newspap year old woman had abus month old son had caus death wa veri angri read not human act abus fragil life not forgiv sin ', 'anger'] disgust anger
# ['had schoolmat went hospit brain wa bleed fell unconsci day went see saw miser state famili wa moreov not noth wa veri sad final die ', 'sadness'] sadness sadness
# ['tiresom person held day long wa veri busi then not rememb problem wa contin tri make talk disturb ', 'disgust'] anger disgust
# ['day wa sit bu wa old woman stand wa veri tire sleepi did not think give seat year old woman wa sit got gave seat old woman said old woman pleas take seat youngstter day are not use give seat other heard word wa veri asham want get bu onc ', 'shame'] shame shame
# ['exam wa veri bad mood had done veri badli home mother took long ask thing had gone lost temper overreact made mother cri still prepar lunch did not scold suddenli thought wa fault start cri ', 'guilt'] guilt guilt
# ['wa appreci other especi famili member friend ', 'joy'] sadness joy
# ['alon dark room walk alon street sleep alon room night see someth onli partli visibl emot wa veri strong year old child saw someth horribl ', 'fear'] fear fear
# ['put other shoe tri make person happi comfort make friend misunderstood reject especi person famili member friend ', 'anger'] guilt anger
# ['wa conflict interest close friend mine onli thought own interest not friendship behaviour hurt friend incid friend isol give reason ', 'sadness'] guilt sadness
# ['saw lot rubbish anim wast floor ', 'disgust'] disgust disgust
# ['wa emot unstabl said thing have hurt other made feel unhappi calm down realiz had been selfish had not taken consider feel other then felt asham someon point behaviour ', 'shame'] guilt shame
# ['break someon thing careless someth make other feel unhappi hurt self-esteem self-confid other especi happen friend famili member ', 'guilt'] guilt guilt
# ['receiv letter inform had been accept chines univers student wa excit had long ', 'joy'] joy joy
# ['day wa littl boy friend ask play outsid catch boy howev parent did not know were out got home wa veri late fear be scold parent ', 'fear'] guilt fear
# ['learnt friend mine had talk friend had said wrong thing abil attitud wa veri angri ', 'anger'] anger anger
# ['year girlfriend suggest separ realli gave shock had never thought say such thing reason gave wa were not suit other ', 'sadness'] sadness sadness
# ['onc studi exam found mani complic word disgust ', 'disgust'] disgust disgust
# ['wa young felt asham rel visit hid ', 'shame'] shame shame
# ['wa excit told classmat wa old hurt felt guilti ', 'guilt'] guilt guilt
# ['certain period felt success extrem satisfi found task decis had made were better expect ', 'joy'] joy joy
# ['scare stroll alon chung chi colleg campu ', 'fear'] fear fear
# ['day discuss veri import question suddenli declar not accept posit thought wa right moreov attack strongli not opinion person ', 'anger'] anger anger
# ['learnt had fail exam not onli influenc emot also other import task also made record imperfect ', 'sadness'] shame sadness
# ['classifi subject certain gestur way talk person disgust inaccept ', 'disgust'] disgust disgust
